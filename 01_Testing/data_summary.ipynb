# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import requests
import os
from pprint import pprint

# %%
games_detailed = os.path.join("01_Resources", "archive", "games_details.csv")
games = os.path.join("01_Resources", "archive", "games.csv")
players = os.path.join("01_Resources", "archive", "players.csv")
ranking = os.path.join("01_Resources", "archive", "ranking.csv")
teams = os.path.join("01_Resources", "archive", "teams.csv")
games_det_df = pd.read_csv(games_detailed, low_memory=False)
games_df = pd.read_csv(games, low_memory=False)
players_df = pd.read_csv(players, low_memory=False)
rankings_df = pd.read_csv(ranking, low_memory=False)
teams_df = pd.read_csv(teams, low_memory=False)

# %% [markdown]
# # Quick Explanation:
#
# ## The 'describe_df' function shows:
# 1) Shape of the Data Frame
# 2) Data Types
# 3) df.describe()

# %%
def describe_df(df):
    print(f'''

Shape of Data Frame:
{df.shape}

DATA TYPES: 

{df.dtypes}

Name of Columns: 
{df.columns} 

COLUMNS DESCRIBED:

{df.describe()}
''')

# %%
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2021-11-17  22100213            Final    1610612766       1610612764
# 1    2021-11-17  22100214            Final    1610612765       1610612754
# 2    2021-11-17  22100215            Final    1610612737       1610612738
# 3    2021-11-17  22100216            Final    1610612751       1610612739
# 4    2021-11-17  22100217            Final    1610612748       1610612740
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2021    1610612766      97.0        0.438        0.500  ...      30.0
# 1    2021    1610612765      97.0        0.425        0.750  ...      16.0
# 2    2021    1610612737     110.0        0.506        0.833  ...      28.0
# 3    2021    1610612751     109.0        0.458        0.840  ...      29.0
# 4    2021    1610612748     113.0        0.483        0.824  ...      29.0
#
# ...

# %%
describe_df(games_df)
# Out:
# Shape of Data Frame:
# (25024, 21)
#
# DATA TYPES:
#
# GAME_DATE_EST        object
# GAME_ID               int64
# GAME_STATUS_TEXT     object
# HOME_TEAM_ID          int64
# VISITOR_TEAM_ID       int64
# SEASON                int64
# TEAM_ID_home          int64
# PTS_home            float64
# FG_PCT_home         float64
# FT_PCT_home         float64
# FG3_PCT_home        float64
# AST_home            float64
# REB_home            float64
# TEAM_ID_away          int64
# PTS_away            float64
# FG_PCT_away         float64
# FT_PCT_away         float64
# FG3_PCT_away        float64
# AST_away            float64
# REB_away            float64
# HOME_TEAM_WINS        int64
# dtype: object
#
# Name of Columns:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
# ...

# %%
players_df.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
describe_df(players_df)
# Out:
# Shape of Data Frame:
# (7228, 4)
#
# DATA TYPES:
#
# PLAYER_NAME    object
# TEAM_ID         int64
# PLAYER_ID       int64
# SEASON          int64
# dtype: object
#
# Name of Columns:
# Index(['PLAYER_NAME', 'TEAM_ID', 'PLAYER_ID', 'SEASON'], dtype='object')
#
# COLUMNS DESCRIBED:
#
#             TEAM_ID     PLAYER_ID       SEASON
# count  7.228000e+03  7.228000e+03  7228.000000
# mean   1.610613e+09  2.355862e+06  2014.159934
# std    8.723521e+00  6.106688e+07     3.126216
# min    1.610613e+09  2.440000e+02  2009.000000
# 25%    1.610613e+09  2.007680e+05  2012.000000
# 50%    1.610613e+09  2.023465e+05  2014.000000
# 75%    1.610613e+09  2.039100e+05  2017.000000
# max    1.610613e+09  1.962938e+09  2019.000000

# %%
rankings_df.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM  \
# 0  1610612744          0      22021    2021-11-17       West  Golden State
# 1  1610612756          0      22021    2021-11-17       West       Phoenix
# 2  1610612742          0      22021    2021-11-17       West        Dallas
# 3  1610612743          0      22021    2021-11-17       West        Denver
# 4  1610612746          0      22021    2021-11-17       West   LA Clippers
#
#     G   W  L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  14  12  2  0.857         8-1         4-1           NaN
# 1  14  11  3  0.786         6-2         5-1           NaN
# 2  14   9  5  0.643         6-1         3-4           NaN
# 3  14   9  5  0.643         7-1         2-4           NaN
# 4  14   9  5  0.643         7-3         2-2           NaN

# %%
describe_df(rankings_df)
# Out:
# Shape of Data Frame:
# (198342, 13)
#
# DATA TYPES:
#
# TEAM_ID            int64
# LEAGUE_ID          int64
# SEASON_ID          int64
# STANDINGSDATE     object
# CONFERENCE        object
# TEAM              object
# G                  int64
# W                  int64
# L                  int64
# W_PCT            float64
# HOME_RECORD       object
# ROAD_RECORD       object
# RETURNTOPLAY     float64
# dtype: object
#
# Name of Columns:
# Index(['TEAM_ID', 'LEAGUE_ID', 'SEASON_ID', 'STANDINGSDATE', 'CONFERENCE',
#        'TEAM', 'G', 'W', 'L', 'W_PCT', 'HOME_RECORD', 'ROAD_RECORD',
#        'RETURNTOPLAY'],
#       dtype='object')
#
# COLUMNS DESCRIBED:
#
#             TEAM_ID  LEAGUE_ID      SEASON_ID              G              W  \
# count  1.983420e+05   198342.0  198342.000000  198342.000000  198342.000000
# mean   1.610613e+09        0.0   21390.760116      56.728323      28.367774
# std    8.640654e+00        0.0    2412.988998      28.616779      17.286137
# ...

# %%
teams_df.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
describe_df(teams_df)
# Out:
# Shape of Data Frame:
# (30, 14)
#
# DATA TYPES:
#
# LEAGUE_ID               int64
# TEAM_ID                 int64
# MIN_YEAR                int64
# MAX_YEAR                int64
# ABBREVIATION           object
# NICKNAME               object
# YEARFOUNDED             int64
# CITY                   object
# ARENA                  object
# ARENACAPACITY         float64
# OWNER                  object
# GENERALMANAGER         object
# HEADCOACH              object
# DLEAGUEAFFILIATION     object
# dtype: object
#
# Name of Columns:
# Index(['LEAGUE_ID', 'TEAM_ID', 'MIN_YEAR', 'MAX_YEAR', 'ABBREVIATION',
#        'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER',
#        'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION'],
#       dtype='object')
#
# COLUMNS DESCRIBED:
#
#        LEAGUE_ID       TEAM_ID     MIN_YEAR  MAX_YEAR  YEARFOUNDED  \
# count       30.0  3.000000e+01    30.000000      30.0    30.000000
# ...
